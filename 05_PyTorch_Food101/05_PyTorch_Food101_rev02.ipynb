# %%
# !rm -r ./Datasets/train
# !rm -r ./Datasets/test
# !rm -r ./saved_models/new_model
# Out:
# rm: ./saved_models/new_model: No such file or directory

# %%
import torch
import os
import pathlib
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from time import time
from torchvision.transforms import v2
from torchvision.datasets import ImageFolder, Food101
from torch.utils.data import DataLoader
from torch import nn
from scripts import utilities, dataset_setup, model_setup

# %% [markdown]
# # VARIABLES NEEDED TO RUN THE TRAINING - GENERAL SETTINGS FOR THE TRAINING

# %%
#the default folder to save new models and the log
MODEL_FOLDER = pathlib.Path(os.getcwd() + '/saved_models/new_model')
LOG_FOLDER = MODEL_FOLDER
FOOD101_PATH = pathlib.Path(os.getcwd() + '/Datasets/food-101') #folder where the original dataset is stored in the  
DATASET_TRAIN_FOLDER = pathlib.Path(os.getcwd() + '/Datasets/train')
DATASET_TEST_FOLDER = pathlib.Path(os.getcwd() + '/Datasets/test')

NUMBER_OF_CLASSES = 5 #number of classes to use for the training
RESIZE = (224, 224)
BATCH_SIZE = 2 ** 5
LEARNING_RATE = 5e-3
#setting up a logger Agent
logger = utilities.Logging_Agent(LOG_FOLDER)

# %%
torch.__version__
# Out:
# '2.6.0'

# %%
os.chdir('/Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101')
os.getcwd()
# Out:
# '/Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101'

# %%
#set your own token and chat_id here if you need telegram messages to be sent to track the execution of your program.    
#use a specific file *.env for the case and store it in a given path

dot_env_path='/Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/TelegramLogIn.env'

from dotenv import load_dotenv
load_dotenv(dot_env_path)
# Out:
# True

# %% [markdown]
# FOOD101_PATH = pathlib.Path(os.getcwd() + '/Datasets')
# print(FOOD101_PATH)
#
# if not FOOD101_PATH.exists():
#     os.makedirs(FOOD101_PATH)
#     Food101(root=FOOD101_PATH, download=True)
#     logger.write_log(f'The Food101 dataset has been downloaded and is available @ {FOOD101_PATH}')
# else:
#     logger.write_log(f'The Food101 dataset already exists @ {FOOD101_PATH}')

# %% [markdown]
# ### First of all let's check whether the dataset has been already downloaded. If not, let's download it from the Torchvision library

# %%
train_test_foods = dataset_setup.dataset_creation(
    food101_folder=FOOD101_PATH,
    dataset_train_folder=DATASET_TRAIN_FOLDER,
    dataset_test_folder=DATASET_TEST_FOLDER,
    logger=logger,
    nr_classes=5,
    picked_foods=['french_fries', 'cup_cakes', 'sushi', 'steak', 'pizza']
)
# Out:
# Creating dataset train and test folders:
# The folders have been created:
# 	/Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train
# 	/Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test
# The picked food french_fries has 1000 samples.
# Copied 800 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train/french_fries
# Copied 200 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test/french_fries
# The picked food cup_cakes has 1000 samples.
# Copied 800 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train/cup_cakes
# Copied 200 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test/cup_cakes
# The picked food sushi has 1000 samples.
# Copied 800 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train/sushi
# Copied 200 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test/sushi
# The picked food steak has 1000 samples.
# Copied 800 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train/steak
# Copied 200 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test/steak
# The picked food pizza has 1000 samples.
# Copied 800 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train/pizza
# Copied 200 files to /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test/pizza

# %% [markdown]
# ### Giving a look at 9 random pictures just copied into the train and test folders

# %%
utilities.plot_samples(
    path=DATASET_TRAIN_FOLDER,
    classes_names=train_test_foods,
)

# %% [markdown]
# ### Let's create a transform function to import the data stored in the folders created and have some data augmentation in the meantime

# %%
transform = nn.Sequential(
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Resize(RESIZE),
    v2.RandomHorizontalFlip(p=0.25),
    v2.RandomVerticalFlip(p=0.25),
    v2.RandomRotation(degrees=30),
    v2.RandomPerspective(p=0.25, distortion_scale=0.2),
)

transform_test = nn.Sequential(
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Resize(RESIZE),
)

utilities.plot_samples_transformed(
    path=DATASET_TRAIN_FOLDER,
    transform=transform,
    classes_names=train_test_foods,
)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].

# %% [markdown]
# ### We create the datasets starting from the folders created and check whether the classes are properly generated

# %%
train_dataset = ImageFolder(root=DATASET_TRAIN_FOLDER, transform=transform)
test_dataset = ImageFolder(root=DATASET_TEST_FOLDER, transform=transform_test)
logger.write_log(f'The datasets have been created...\n\tThe train dataset has {len(train_dataset):_} images\n\tThe test dataset has {len(test_dataset):_} images')
# Out:
# The datasets have been created...
# 	The train dataset has 4_000 images
# 	The test dataset has 1_000 images

# %%
train_dataset,test_dataset
# Out:
# (Dataset ImageFolder
#      Number of datapoints: 4000
#      Root location: /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/train
#      StandardTransform
#  Transform: Sequential(
#               (0): ToImage()
#               (1): ToDtype(scale=True)
#               (2): Resize(size=[224, 224], interpolation=InterpolationMode.BILINEAR, antialias=True)
#               (3): RandomHorizontalFlip(p=0.25)
#               (4): RandomVerticalFlip(p=0.25)
#               (5): RandomRotation(degrees=[-30.0, 30.0], interpolation=InterpolationMode.NEAREST, expand=False, fill=0)
#               (6): RandomPerspective(p=0.25, distortion_scale=0.2, interpolation=InterpolationMode.BILINEAR, fill=0)
#             ),
#  Dataset ImageFolder
#      Number of datapoints: 1000
#      Root location: /Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/Datasets/test
#      StandardTransform
#  Transform: Sequential(
#               (0): ToImage()
#               (1): ToDtype(scale=True)
#               (2): Resize(size=[224, 224], interpolation=InterpolationMode.BILINEAR, antialias=True)
#             ))

# %%
logger.write_log(f'The classes of the datasets are mapped like so: \n\t{train_dataset.class_to_idx}')
# Out:
# The classes of the datasets are mapped like so:
# 	{'cup_cakes': 0, 'french_fries': 1, 'pizza': 2, 'steak': 3, 'sushi': 4}

# %% [markdown]
# ### Finally we create a DataLoader

# %%
train_batches = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_batches = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
logger.write_log(f'The dataloaders are on, with batch size {BATCH_SIZE}')
logger.write_log(f'Number of batches (training): {len(train_batches)}')
# Out:
# The dataloaders are on, with batch size 32
# Number of batches (training): 125

# %% [markdown]
# ### MPS agnostic code setting

# %%
device = 'mps' if torch.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu'
logger.write_log(f'Using {device} device')
# Out:
# Using mps device

# %% [markdown]
# ### Creating a model0 class and instantiating it...

# %%
model0 = model_setup.TinyVGG(
    name='TinyVGG',
    input_size=3,
    first_hidden_channels=10,
    second_hidden_channels=15,
    first_hidden_linear_nodes=15 * 56 * 56,
    output_size=NUMBER_OF_CLASSES,
)

# %%
from torchinfo import summary

model_info = summary(model0, input_size=[16, 3, 224, 224])

with open(MODEL_FOLDER / 'model_info.txt', 'w') as f:
    f.write(str(model_info))

model_info
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGG                                  [16, 5]                   --
# ├─Sequential: 1-1                        [16, 10, 112, 112]        --
# │    └─Conv2d: 2-1                       [16, 10, 224, 224]        280
# │    └─ReLU: 2-2                         [16, 10, 224, 224]        --
# │    └─Conv2d: 2-3                       [16, 10, 224, 224]        910
# │    └─ReLU: 2-4                         [16, 10, 224, 224]        --
# │    └─MaxPool2d: 2-5                    [16, 10, 112, 112]        --
# ├─Sequential: 1-2                        [16, 15, 56, 56]          --
# │    └─Conv2d: 2-6                       [16, 15, 112, 112]        1,365
# │    └─ReLU: 2-7                         [16, 15, 112, 112]        --
# │    └─Conv2d: 2-8                       [16, 15, 112, 112]        2,040
# │    └─ReLU: 2-9                         [16, 15, 112, 112]        --
# │    └─MaxPool2d: 2-10                   [16, 15, 56, 56]          --
# ├─Sequential: 1-3                        [16, 5]                   --
# │    └─Flatten: 2-11                     [16, 47040]               --
# │    └─Linear: 2-12                      [16, 5]                   235,205
# ==========================================================================================
# Total params: 239,800
# Trainable params: 239,800
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.64
# ==========================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 176.62
# Params size (MB): 0.96
# Estimated Total Size (MB): 187.21
# ==========================================================================================

# %%
model0.to(device=device)
logger.write_log(f'The model is created and loaded on: {next(model0.parameters()).device}')
# Out:
# The model is created and loaded on: mps:0

# %%
#testing the model functionality with the first picture in the dataloader. Just to see whether the outcome is consistent with what we expect or not:
test_pic = next(iter(train_batches))[0][0].unsqueeze(dim=0).to(device=device)
model0.eval()
with torch.no_grad():
    outcome_test = model0(test_pic)

logger.write_log(f'The outcome of the tast performed on the first picture fetched from the dataloader is: '
      f'\n\tLOGITS: {outcome_test}'
      f'\n\tPROBABILITIES: {torch.softmax(outcome_test, dim=1)}'
      f'\n\tPREDICTED CLASS: {torch.argmax(torch.softmax(outcome_test, dim=1), dim=1).item()}')
# Out:
# The outcome of the tast performed on the first picture fetched from the dataloader is:
# 	LOGITS: tensor([[-0.0120, -0.0592, -0.0307, -0.0342, -0.0065]], device='mps:0')
# 	PROBABILITIES: tensor([[0.2033, 0.1939, 0.1995, 0.1988, 0.2044]], device='mps:0')
# 	PREDICTED CLASS: 4

# %% [markdown]
# ### We set an optimizer and a loss function with the latter being a CrossEntropyLossFunction from torch.nn (<a href='https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss'>link</a>)

# %%
ce_loss = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model0.parameters(), lr=LEARNING_RATE)

logger.write_log(f'The Learning Rate is set to {LEARNING_RATE} | Optimizer is on and ready...')
# Out:
# The Learning Rate is set to 0.005 | Optimizer is on and ready...

# %%
from tqdm.auto import tqdm
epochs = 0
end_epochs = 50

utilities.send_telegram('Training started...')

start_time = time()
for epoch in range(epochs, end_epochs):
    logger.write_log(f'EPOCH NUMBER: {epoch + 1} out of {end_epochs}')
    train_loss = []
    cv_loss = []
    train_acc = []
    cv_acc = []
    start_time_epoch = time() #marking the starting time for the epoch training
    for batch_index, (batch_X, batch_y) in enumerate(train_batches):
        
        start_time_batch = time()
        
        #training step per every batch. the function returns the loss and accuracy
        model0.train() #switches on the train mode from torch module
        loss_batch, acc_batch = model0.train_step(batch_X=batch_X, 
                                                  batch_y=batch_y,
                                                  optimizer=optimizer, 
                                                  loss_foo=ce_loss,
                                                  device=device)

        #appending the losses computed for the batch to the container for the whole epoch
        train_loss.append(loss_batch)
        train_acc.append(acc_batch)
        
        end_time_batch = time()
        
        if batch_index % 50 == 0:
            resume_batch = model0.write_minibatch_results_class(
                batch_index=batch_index,
                batch_quantity=len(train_batches),
                train_loss=train_loss,
                batch_loss_train=loss_batch,
                train_acc=train_acc,
                batch_acc_train=acc_batch,
                start_time_iteration=start_time_batch,
                end_time_iteration=end_time_batch
            )
            logger.write_log(resume_batch)
            
    #5. CrossValidation step (once per epoch...)
    model0.eval()
    for batch_test_X, batch_test_y in test_batches:
        loss_batch_cv, acc_batch_cv = model0.eval_step(
            batch_test_X=batch_test_X,
            batch_test_y=batch_test_y,
            loss_foo=ce_loss,
            device=device
        )
            
        #appending the losses computed for the batch to the container for the whole epoch
        cv_loss.append(loss_batch_cv)
        cv_acc.append(acc_batch_cv)
        
    #marking the end time for the epoch training
    end_time_epoch = time()
    epoch_resume = model0.write_epoch_results_class(
        curr_iteration=epoch,
        last_iteration=end_epochs,
        train_loss=train_loss,
        train_acc=train_acc,
        cv_loss=cv_loss,
        cv_acc=cv_acc,
        end_time_iteration=end_time_epoch,
        start_time_iteration=start_time_epoch
    )
    logger.write_log(epoch_resume)
    utilities.send_telegram(epoch_resume)

    #keep track of the history of the training metrics
    model0.history_update('train_loss', np.mean(train_loss).item())
    model0.history_update('train_acc', np.mean(train_acc).item())
    model0.history_update('cv_loss', np.mean(cv_loss).item())
    model0.history_update('cv_acc', np.mean(cv_acc).item())
    
    if epoch % 20 == 0 & epoch != 0:
        utilities.save_model(
            path=MODEL_FOLDER,
            model=model0,
            optimizer=optimizer,
            epoch_nr=end_epochs,
            learning_rate=LEARNING_RATE,
            batch_size=BATCH_SIZE,
            nr_classes=NUMBER_OF_CLASSES
        )
        logger.write_log(f'Model and optimizer saved for the checkpoint @epoch nr.: {epoch}')

end_time = time()
utilities.send_telegram('Training closed succesfully...')
# Out:
# EPOCH NUMBER: 1 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.606 (last:    1.606) | Train Acc. epoch: 31.25% (last: 31.25%) | Elapsed Time: 0.2 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.613 (last:    1.605) | Train Acc. epoch: 19.85% (last: 21.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.611 (last:    1.595) | Train Acc. epoch: 20.42% (last: 21.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 1 out of 50
# 	Train loss: 1.610 | Train Accuracy: 20.800%
# 	CV loss:    1.602 | CV Accuracy:    22.363%
# 	Time taken: 17.35 seconds
# EPOCH NUMBER: 2 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.610 (last:    1.610) | Train Acc. epoch: 15.62% (last: 15.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.598 (last:    1.564) | Train Acc. epoch: 24.20% (last: 28.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.594 (last:    1.601) | Train Acc. epoch: 25.80% (last: 15.62%) | Elapsed Time: 0.0 sec.
# Epoch number: 2 out of 50
# 	Train loss: 1.590 | Train Accuracy: 27.200%
# 	CV loss:    1.572 | CV Accuracy:    27.539%
# 	Time taken: 17.42 seconds
# EPOCH NUMBER: 3 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.540 (last:    1.540) | Train Acc. epoch: 43.75% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.552 (last:    1.528) | Train Acc. epoch: 31.56% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.534 (last:    1.594) | Train Acc. epoch: 32.36% (last: 25.00%) | Elapsed Time: 0.0 sec.
# Epoch number: 3 out of 50
# 	Train loss: 1.529 | Train Accuracy: 32.850%
# 	CV loss:    1.479 | CV Accuracy:    34.668%
# 	Time taken: 15.69 seconds
# EPOCH NUMBER: 4 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.477 (last:    1.477) | Train Acc. epoch: 37.50% (last: 37.50%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.491 (last:    1.538) | Train Acc. epoch: 33.27% (last: 28.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.474 (last:    1.392) | Train Acc. epoch: 34.84% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 4 out of 50
# 	Train loss: 1.472 | Train Accuracy: 34.475%
# 	CV loss:    1.445 | CV Accuracy:    37.207%
# 	Time taken: 14.99 seconds
# EPOCH NUMBER: 5 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.290 (last:    1.290) | Train Acc. epoch: 62.50% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.448 (last:    1.414) | Train Acc. epoch: 34.87% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.453 (last:    1.416) | Train Acc. epoch: 35.27% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 5 out of 50
# 	Train loss: 1.448 | Train Accuracy: 35.975%
# 	CV loss:    1.423 | CV Accuracy:    37.793%
# 	Time taken: 16.23 seconds
# EPOCH NUMBER: 6 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.367 (last:    1.367) | Train Acc. epoch: 34.38% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.455 (last:    1.512) | Train Acc. epoch: 35.85% (last: 25.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.437 (last:    1.446) | Train Acc. epoch: 37.31% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 6 out of 50
# 	Train loss: 1.435 | Train Accuracy: 37.050%
# 	CV loss:    1.398 | CV Accuracy:    39.941%
# 	Time taken: 15.52 seconds
# EPOCH NUMBER: 7 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.429 (last:    1.429) | Train Acc. epoch: 46.88% (last: 46.88%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.402 (last:    1.465) | Train Acc. epoch: 39.77% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.398 (last:    1.190) | Train Acc. epoch: 40.66% (last: 62.50%) | Elapsed Time: 0.1 sec.
# Epoch number: 7 out of 50
# 	Train loss: 1.397 | Train Accuracy: 40.525%
# 	CV loss:    1.353 | CV Accuracy:    44.043%
# 	Time taken: 19.59 seconds
# EPOCH NUMBER: 8 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.366 (last:    1.366) | Train Acc. epoch: 43.75% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.367 (last:    1.381) | Train Acc. epoch: 42.16% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.352 (last:    1.635) | Train Acc. epoch: 43.84% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 8 out of 50
# 	Train loss: 1.347 | Train Accuracy: 43.675%
# 	CV loss:    1.367 | CV Accuracy:    40.039%
# 	Time taken: 14.91 seconds
# EPOCH NUMBER: 9 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.077 (last:    1.077) | Train Acc. epoch: 62.50% (last: 62.50%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.333 (last:    1.292) | Train Acc. epoch: 45.16% (last: 50.00%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.320 (last:    1.149) | Train Acc. epoch: 45.98% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Epoch number: 9 out of 50
# 	Train loss: 1.322 | Train Accuracy: 45.675%
# 	CV loss:    1.289 | CV Accuracy:    47.852%
# 	Time taken: 23.34 seconds
# EPOCH NUMBER: 10 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.248 (last:    1.248) | Train Acc. epoch: 43.75% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.319 (last:    1.589) | Train Acc. epoch: 45.34% (last: 31.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.310 (last:    1.055) | Train Acc. epoch: 45.64% (last: 68.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 10 out of 50
# 	Train loss: 1.303 | Train Accuracy: 45.650%
# 	CV loss:    1.281 | CV Accuracy:    48.242%
# 	Time taken: 19.10 seconds
# EPOCH NUMBER: 11 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.295 (last:    1.295) | Train Acc. epoch: 43.75% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.301 (last:    1.458) | Train Acc. epoch: 45.59% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.298 (last:    1.433) | Train Acc. epoch: 46.16% (last: 31.25%) | Elapsed Time: 0.0 sec.
# Epoch number: 11 out of 50
# 	Train loss: 1.293 | Train Accuracy: 46.775%
# 	CV loss:    1.335 | CV Accuracy:    46.387%
# 	Time taken: 16.76 seconds
# EPOCH NUMBER: 12 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.119 (last:    1.119) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.262 (last:    1.139) | Train Acc. epoch: 49.75% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.280 (last:    1.349) | Train Acc. epoch: 48.42% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 12 out of 50
# 	Train loss: 1.287 | Train Accuracy: 47.950%
# 	CV loss:    1.289 | CV Accuracy:    46.484%
# 	Time taken: 16.68 seconds
# EPOCH NUMBER: 13 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.233 (last:    1.233) | Train Acc. epoch: 56.25% (last: 56.25%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.288 (last:    1.290) | Train Acc. epoch: 47.61% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.281 (last:    1.533) | Train Acc. epoch: 48.14% (last: 25.00%) | Elapsed Time: 0.0 sec.
# Epoch number: 13 out of 50
# 	Train loss: 1.280 | Train Accuracy: 48.000%
# 	CV loss:    1.287 | CV Accuracy:    49.414%
# 	Time taken: 16.70 seconds
# EPOCH NUMBER: 14 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.341 (last:    1.341) | Train Acc. epoch: 40.62% (last: 40.62%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.257 (last:    1.156) | Train Acc. epoch: 48.71% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.272 (last:    1.225) | Train Acc. epoch: 47.34% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 14 out of 50
# 	Train loss: 1.272 | Train Accuracy: 47.575%
# 	CV loss:    1.258 | CV Accuracy:    49.121%
# 	Time taken: 16.72 seconds
# EPOCH NUMBER: 15 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.641 (last:    1.641) | Train Acc. epoch: 34.38% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.244 (last:    1.043) | Train Acc. epoch: 49.69% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.252 (last:    1.280) | Train Acc. epoch: 49.60% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Epoch number: 15 out of 50
# 	Train loss: 1.264 | Train Accuracy: 48.400%
# 	CV loss:    1.271 | CV Accuracy:    47.949%
# 	Time taken: 16.34 seconds
# EPOCH NUMBER: 16 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.087 (last:    1.087) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.278 (last:    1.306) | Train Acc. epoch: 47.67% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.259 (last:    1.427) | Train Acc. epoch: 48.45% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Epoch number: 16 out of 50
# 	Train loss: 1.263 | Train Accuracy: 47.900%
# 	CV loss:    1.259 | CV Accuracy:    50.391%
# 	Time taken: 17.46 seconds
# EPOCH NUMBER: 17 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.182 (last:    1.182) | Train Acc. epoch: 59.38% (last: 59.38%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.245 (last:    1.409) | Train Acc. epoch: 48.59% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.256 (last:    1.333) | Train Acc. epoch: 47.96% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 17 out of 50
# 	Train loss: 1.256 | Train Accuracy: 48.400%
# 	CV loss:    1.251 | CV Accuracy:    50.879%
# 	Time taken: 17.42 seconds
# EPOCH NUMBER: 18 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.100 (last:    1.100) | Train Acc. epoch: 62.50% (last: 62.50%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.218 (last:    1.367) | Train Acc. epoch: 50.86% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.249 (last:    1.342) | Train Acc. epoch: 48.82% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Epoch number: 18 out of 50
# 	Train loss: 1.253 | Train Accuracy: 48.650%
# 	CV loss:    1.273 | CV Accuracy:    49.609%
# 	Time taken: 17.26 seconds
# EPOCH NUMBER: 19 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.233 (last:    1.233) | Train Acc. epoch: 50.00% (last: 50.00%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.268 (last:    1.375) | Train Acc. epoch: 47.92% (last: 37.50%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.248 (last:    1.022) | Train Acc. epoch: 49.29% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Epoch number: 19 out of 50
# 	Train loss: 1.252 | Train Accuracy: 49.200%
# 	CV loss:    1.327 | CV Accuracy:    47.754%
# 	Time taken: 16.85 seconds
# EPOCH NUMBER: 20 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.229 (last:    1.229) | Train Acc. epoch: 50.00% (last: 50.00%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.245 (last:    1.272) | Train Acc. epoch: 50.12% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.249 (last:    1.082) | Train Acc. epoch: 49.35% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Epoch number: 20 out of 50
# 	Train loss: 1.244 | Train Accuracy: 49.225%
# 	CV loss:    1.256 | CV Accuracy:    50.391%
# 	Time taken: 16.67 seconds
# EPOCH NUMBER: 21 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.034 (last:    1.034) | Train Acc. epoch: 68.75% (last: 68.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.253 (last:    1.317) | Train Acc. epoch: 49.75% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.250 (last:    1.120) | Train Acc. epoch: 49.69% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 21 out of 50
# 	Train loss: 1.247 | Train Accuracy: 49.400%
# 	CV loss:    1.258 | CV Accuracy:    48.828%
# 	Time taken: 16.54 seconds
# EPOCH NUMBER: 22 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.217 (last:    1.217) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.227 (last:    1.167) | Train Acc. epoch: 50.74% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.242 (last:    1.109) | Train Acc. epoch: 49.54% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Epoch number: 22 out of 50
# 	Train loss: 1.242 | Train Accuracy: 49.475%
# 	CV loss:    1.272 | CV Accuracy:    47.754%
# 	Time taken: 17.66 seconds
# EPOCH NUMBER: 23 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.308 (last:    1.308) | Train Acc. epoch: 56.25% (last: 56.25%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.228 (last:    1.180) | Train Acc. epoch: 48.71% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.246 (last:    1.079) | Train Acc. epoch: 48.30% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Epoch number: 23 out of 50
# 	Train loss: 1.242 | Train Accuracy: 48.850%
# 	CV loss:    1.317 | CV Accuracy:    45.410%
# 	Time taken: 16.72 seconds
# EPOCH NUMBER: 24 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.299 (last:    1.299) | Train Acc. epoch: 43.75% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.233 (last:    1.352) | Train Acc. epoch: 49.75% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.239 (last:    1.275) | Train Acc. epoch: 48.48% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 24 out of 50
# 	Train loss: 1.237 | Train Accuracy: 48.775%
# 	CV loss:    1.253 | CV Accuracy:    50.195%
# 	Time taken: 16.71 seconds
# EPOCH NUMBER: 25 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.400 (last:    1.400) | Train Acc. epoch: 37.50% (last: 37.50%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.233 (last:    1.122) | Train Acc. epoch: 50.25% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.236 (last:    1.202) | Train Acc. epoch: 49.69% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Epoch number: 25 out of 50
# 	Train loss: 1.234 | Train Accuracy: 50.025%
# 	CV loss:    1.243 | CV Accuracy:    50.098%
# 	Time taken: 15.63 seconds
# EPOCH NUMBER: 26 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.234 (last:    1.234) | Train Acc. epoch: 43.75% (last: 43.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.223 (last:    1.191) | Train Acc. epoch: 50.92% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.216 (last:    0.948) | Train Acc. epoch: 51.21% (last: 68.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 26 out of 50
# 	Train loss: 1.229 | Train Accuracy: 50.450%
# 	CV loss:    1.292 | CV Accuracy:    48.535%
# 	Time taken: 14.89 seconds
# EPOCH NUMBER: 27 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    0.978 (last:    0.978) | Train Acc. epoch: 59.38% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.240 (last:    0.952) | Train Acc. epoch: 50.25% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.232 (last:    1.210) | Train Acc. epoch: 50.62% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Epoch number: 27 out of 50
# 	Train loss: 1.221 | Train Accuracy: 51.275%
# 	CV loss:    1.223 | CV Accuracy:    51.855%
# 	Time taken: 14.71 seconds
# EPOCH NUMBER: 28 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.135 (last:    1.135) | Train Acc. epoch: 59.38% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.235 (last:    1.488) | Train Acc. epoch: 49.94% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.215 (last:    1.101) | Train Acc. epoch: 51.27% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Epoch number: 28 out of 50
# 	Train loss: 1.220 | Train Accuracy: 50.825%
# 	CV loss:    1.253 | CV Accuracy:    50.586%
# 	Time taken: 14.54 seconds
# EPOCH NUMBER: 29 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.446 (last:    1.446) | Train Acc. epoch: 56.25% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.206 (last:    1.390) | Train Acc. epoch: 52.45% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.218 (last:    1.174) | Train Acc. epoch: 51.24% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 29 out of 50
# 	Train loss: 1.216 | Train Accuracy: 51.525%
# 	CV loss:    1.221 | CV Accuracy:    52.051%
# 	Time taken: 15.24 seconds
# EPOCH NUMBER: 30 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.185 (last:    1.185) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.199 (last:    1.172) | Train Acc. epoch: 52.33% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.212 (last:    1.373) | Train Acc. epoch: 51.67% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 30 out of 50
# 	Train loss: 1.212 | Train Accuracy: 51.500%
# 	CV loss:    1.242 | CV Accuracy:    48.730%
# 	Time taken: 14.84 seconds
# EPOCH NUMBER: 31 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.559 (last:    1.559) | Train Acc. epoch: 34.38% (last: 34.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.215 (last:    1.271) | Train Acc. epoch: 50.49% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.210 (last:    1.116) | Train Acc. epoch: 50.62% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 31 out of 50
# 	Train loss: 1.212 | Train Accuracy: 50.775%
# 	CV loss:    1.272 | CV Accuracy:    49.023%
# 	Time taken: 14.68 seconds
# EPOCH NUMBER: 32 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.322 (last:    1.322) | Train Acc. epoch: 40.62% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.237 (last:    1.341) | Train Acc. epoch: 49.75% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.218 (last:    0.997) | Train Acc. epoch: 51.05% (last: 71.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 32 out of 50
# 	Train loss: 1.210 | Train Accuracy: 51.325%
# 	CV loss:    1.228 | CV Accuracy:    49.609%
# 	Time taken: 15.26 seconds
# EPOCH NUMBER: 33 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.178 (last:    1.178) | Train Acc. epoch: 56.25% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.202 (last:    1.063) | Train Acc. epoch: 52.27% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.206 (last:    1.008) | Train Acc. epoch: 52.57% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Epoch number: 33 out of 50
# 	Train loss: 1.198 | Train Accuracy: 52.725%
# 	CV loss:    1.218 | CV Accuracy:    52.832%
# 	Time taken: 15.84 seconds
# EPOCH NUMBER: 34 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.181 (last:    1.181) | Train Acc. epoch: 50.00% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.185 (last:    1.280) | Train Acc. epoch: 52.70% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.195 (last:    1.113) | Train Acc. epoch: 51.73% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 34 out of 50
# 	Train loss: 1.198 | Train Accuracy: 52.050%
# 	CV loss:    1.211 | CV Accuracy:    51.367%
# 	Time taken: 16.34 seconds
# EPOCH NUMBER: 35 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.381 (last:    1.381) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.208 (last:    1.077) | Train Acc. epoch: 52.21% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.197 (last:    1.058) | Train Acc. epoch: 52.75% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Epoch number: 35 out of 50
# 	Train loss: 1.199 | Train Accuracy: 52.250%
# 	CV loss:    1.230 | CV Accuracy:    51.367%
# 	Time taken: 16.30 seconds
# EPOCH NUMBER: 36 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.126 (last:    1.126) | Train Acc. epoch: 50.00% (last: 50.00%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.186 (last:    1.219) | Train Acc. epoch: 54.29% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.193 (last:    1.181) | Train Acc. epoch: 53.22% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 36 out of 50
# 	Train loss: 1.190 | Train Accuracy: 53.300%
# 	CV loss:    1.219 | CV Accuracy:    51.270%
# 	Time taken: 16.05 seconds
# EPOCH NUMBER: 37 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.291 (last:    1.291) | Train Acc. epoch: 40.62% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.189 (last:    1.102) | Train Acc. epoch: 53.49% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.173 (last:    1.094) | Train Acc. epoch: 53.93% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Epoch number: 37 out of 50
# 	Train loss: 1.179 | Train Accuracy: 53.575%
# 	CV loss:    1.206 | CV Accuracy:    52.637%
# 	Time taken: 16.15 seconds
# EPOCH NUMBER: 38 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.236 (last:    1.236) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.224 (last:    1.106) | Train Acc. epoch: 51.65% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.190 (last:    1.321) | Train Acc. epoch: 52.82% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 38 out of 50
# 	Train loss: 1.189 | Train Accuracy: 52.875%
# 	CV loss:    1.209 | CV Accuracy:    51.562%
# 	Time taken: 15.94 seconds
# EPOCH NUMBER: 39 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.251 (last:    1.251) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.160 (last:    0.947) | Train Acc. epoch: 54.11% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.178 (last:    0.994) | Train Acc. epoch: 52.97% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Epoch number: 39 out of 50
# 	Train loss: 1.177 | Train Accuracy: 52.850%
# 	CV loss:    1.215 | CV Accuracy:    51.953%
# 	Time taken: 15.87 seconds
# EPOCH NUMBER: 40 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.472 (last:    1.472) | Train Acc. epoch: 50.00% (last: 50.00%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.150 (last:    0.969) | Train Acc. epoch: 54.96% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.162 (last:    1.165) | Train Acc. epoch: 54.12% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Epoch number: 40 out of 50
# 	Train loss: 1.176 | Train Accuracy: 53.400%
# 	CV loss:    1.234 | CV Accuracy:    50.977%
# 	Time taken: 15.84 seconds
# EPOCH NUMBER: 41 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.251 (last:    1.251) | Train Acc. epoch: 46.88% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.199 (last:    1.087) | Train Acc. epoch: 54.23% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.165 (last:    1.078) | Train Acc. epoch: 54.49% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 41 out of 50
# 	Train loss: 1.168 | Train Accuracy: 54.475%
# 	CV loss:    1.230 | CV Accuracy:    49.805%
# 	Time taken: 15.75 seconds
# EPOCH NUMBER: 42 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    0.969 (last:    0.969) | Train Acc. epoch: 68.75% (last: 68.75%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.171 (last:    1.358) | Train Acc. epoch: 55.15% (last: 40.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.170 (last:    1.084) | Train Acc. epoch: 54.49% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 42 out of 50
# 	Train loss: 1.170 | Train Accuracy: 54.400%
# 	CV loss:    1.204 | CV Accuracy:    50.000%
# 	Time taken: 14.92 seconds
# EPOCH NUMBER: 43 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.050 (last:    1.050) | Train Acc. epoch: 50.00% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.170 (last:    1.045) | Train Acc. epoch: 54.17% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.158 (last:    1.247) | Train Acc. epoch: 54.33% (last: 37.50%) | Elapsed Time: 0.0 sec.
# Epoch number: 43 out of 50
# 	Train loss: 1.159 | Train Accuracy: 54.150%
# 	CV loss:    1.195 | CV Accuracy:    54.297%
# 	Time taken: 15.25 seconds
# EPOCH NUMBER: 44 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.272 (last:    1.272) | Train Acc. epoch: 59.38% (last: 59.38%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.158 (last:    1.103) | Train Acc. epoch: 54.23% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.160 (last:    1.199) | Train Acc. epoch: 54.83% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Epoch number: 44 out of 50
# 	Train loss: 1.165 | Train Accuracy: 54.650%
# 	CV loss:    1.237 | CV Accuracy:    52.051%
# 	Time taken: 16.25 seconds
# EPOCH NUMBER: 45 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.004 (last:    1.004) | Train Acc. epoch: 62.50% (last: 62.50%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.173 (last:    1.116) | Train Acc. epoch: 54.66% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.174 (last:    1.174) | Train Acc. epoch: 54.73% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Epoch number: 45 out of 50
# 	Train loss: 1.166 | Train Accuracy: 54.700%
# 	CV loss:    1.208 | CV Accuracy:    50.879%
# 	Time taken: 14.66 seconds
# EPOCH NUMBER: 46 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.083 (last:    1.083) | Train Acc. epoch: 59.38% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.165 (last:    1.243) | Train Acc. epoch: 53.86% (last: 50.00%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.161 (last:    1.237) | Train Acc. epoch: 54.89% (last: 46.88%) | Elapsed Time: 0.0 sec.
# Epoch number: 46 out of 50
# 	Train loss: 1.156 | Train Accuracy: 54.875%
# 	CV loss:    1.213 | CV Accuracy:    52.344%
# 	Time taken: 14.65 seconds
# EPOCH NUMBER: 47 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.100 (last:    1.100) | Train Acc. epoch: 53.12% (last: 53.12%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.127 (last:    1.107) | Train Acc. epoch: 56.80% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.143 (last:    1.090) | Train Acc. epoch: 55.48% (last: 62.50%) | Elapsed Time: 0.1 sec.
# Epoch number: 47 out of 50
# 	Train loss: 1.148 | Train Accuracy: 54.825%
# 	CV loss:    1.182 | CV Accuracy:    53.711%
# 	Time taken: 18.58 seconds
# EPOCH NUMBER: 48 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.053 (last:    1.053) | Train Acc. epoch: 65.62% (last: 65.62%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.164 (last:    1.142) | Train Acc. epoch: 55.45% (last: 43.75%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.147 (last:    0.998) | Train Acc. epoch: 56.53% (last: 68.75%) | Elapsed Time: 0.0 sec.
# Epoch number: 48 out of 50
# 	Train loss: 1.153 | Train Accuracy: 55.750%
# 	CV loss:    1.216 | CV Accuracy:    51.953%
# 	Time taken: 14.74 seconds
# EPOCH NUMBER: 49 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    1.306 (last:    1.306) | Train Acc. epoch: 56.25% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.149 (last:    1.196) | Train Acc. epoch: 55.70% (last: 56.25%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.146 (last:    0.932) | Train Acc. epoch: 55.01% (last: 65.62%) | Elapsed Time: 0.0 sec.
# Epoch number: 49 out of 50
# 	Train loss: 1.142 | Train Accuracy: 55.725%
# 	CV loss:    1.166 | CV Accuracy:    55.176%
# 	Time taken: 14.63 seconds
# EPOCH NUMBER: 50 out of 50
# Intermediate results for batch 000 out of 125: Train Loss epoch:    0.976 (last:    0.976) | Train Acc. epoch: 68.75% (last: 68.75%) | Elapsed Time: 0.1 sec.
# Intermediate results for batch 050 out of 125: Train Loss epoch:    1.122 (last:    1.120) | Train Acc. epoch: 57.23% (last: 59.38%) | Elapsed Time: 0.0 sec.
# Intermediate results for batch 100 out of 125: Train Loss epoch:    1.143 (last:    0.895) | Train Acc. epoch: 56.03% (last: 75.00%) | Elapsed Time: 0.0 sec.
# Epoch number: 50 out of 50
# 	Train loss: 1.139 | Train Accuracy: 55.900%
# 	CV loss:    1.209 | CV Accuracy:    50.781%
# 	Time taken: 14.59 seconds

# %%
utilities.save_model(
    path=MODEL_FOLDER,
    model=model0,
    optimizer=optimizer,
    epoch_nr=end_epochs,
    learning_rate=LEARNING_RATE,
    batch_size=BATCH_SIZE,
    nr_classes=NUMBER_OF_CLASSES
)
# Out:
# Model metrics history saved in :
# 	/Users/thomaspierantozzi/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/saved_models/new_model

# %%
import matplotlib.pyplot as plt
metrics = [('train_loss', 'train_acc'),
           ('cv_loss', 'cv_acc')]

fig = plt.figure(figsize=[15, 5], dpi=150)
for index, (loss, acc) in enumerate(metrics):
    fig.add_subplot(1, 2, index + 1)
    plt.plot(
        np.arange(len(model0.history[loss])),
        model0.history[loss],
        label=loss,
        color='red',
        linewidth = 0.75,
    )
    plt.plot(
        np.arange(len(model0.history[loss])),
        model0.history[acc],
        label = acc,
        color='black',
        linewidth = 0.75,
        linestyle='--'
    )
    plt.legend()
    plt.title(f'{loss } VS. {acc}')


    plt.grid(linestyle='--', color='gray')

plt.savefig(MODEL_FOLDER / 'loss_acc_history.jpg')

# %%
fig = plt.figure(figsize=[15, 5], dpi=150)
plt.plot(np.arange(len(model0.history[loss])), model0.history['train_loss'], color='orange', label='train_loss')
plt.plot(np.arange(len(model0.history[loss])), model0.history['cv_loss'], color='blue', label='cv_loss')
plt.title('LOSS COMPARISON')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(linewidth='.5', linestyle='--', color='gray')
plt.savefig(MODEL_FOLDER / 'loss_comparison.jpg')

# %%
model0.to(device='mps')
model0.compute_outcome(train_batches, test_batches, ce_loss)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 model0.to(device='mps')
# ----> 2 model0.compute_outcome(train_batches, test_batches, ce_loss)
#
# File ~/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/scripts/model_setup.py:54, in Model_Blueprint.compute_outcome(self, train_dataloader, test_dataloader, loss_foo)
#      51 test_acc = []
#      53 for X_batch, y_batch in train_dataloader:
# ---> 54     train_loss_batch, train_acc_batch = self.eval_step(X_batch, y_batch, self, loss_foo)
#      55     train_losses.append(train_loss_batch)
#      56     train_acc.append(train_acc_batch)
#
# File ~/PycharmProjects/PyTorch_Train/05_PyTorch_Food101/scripts/model_setup.py:170, in Model_Blueprint.eval_step(self, batch_test_X, batch_test_y, loss_foo, device)
#     167 # 5. CrossValidation step
#     168 with torch.no_grad():
#     169     # 0. Sending the batches to the correct device
# --> 170     batch_test_X, batch_test_y = batch_test_X.to(device=device), batch_test_y.to(device=device)
#     172     # 1. forward
#     173     y_hat_cv = self.forward(batch_test_X)
#
# TypeError: to() received an invalid combination of arguments - got (device=CrossEntropyLoss, ), but expected one of:
#  * (torch.device device = None, torch.dtype dtype = None, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#  * (torch.dtype dtype, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#  * (Tensor tensor, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)

# %%
train_dataset.class_to_idx
