# %%
import pandas as pd

# %%
df = pd.read_csv('./ModelChoice.csv', sep=';')

# %%
list_columns = ['Acc@1', 'Acc@5', 'Params']
for col in list_columns:
    df[col] = df[col].str.replace(',', '.', regex=True)

df[list_columns] = df[list_columns].astype('float32')
df
# Out:
#                                      Weight      Acc@1      Acc@5      Params
# 0             AlexNet_Weights.IMAGENET1K_V1  56.521999  79.066002   61.099998
# 1       ConvNeXt_Base_Weights.IMAGENET1K_V1  84.061996  96.870003   88.599998
# 2      ConvNeXt_Large_Weights.IMAGENET1K_V1  84.414001  96.975998  197.800003
# 3      ConvNeXt_Small_Weights.IMAGENET1K_V1  83.615997  96.650002   50.200001
# 4       ConvNeXt_Tiny_Weights.IMAGENET1K_V1  82.519997  96.146004   28.600000
# ..                                      ...        ...        ...         ...
# 109          ViT_L_32_Weights.IMAGENET1K_V1  76.972000  93.070000  306.500000
# 110  Wide_ResNet101_2_Weights.IMAGENET1K_V1  78.848000  94.283997  126.900002
# 111  Wide_ResNet101_2_Weights.IMAGENET1K_V2  82.510002  96.019997  126.900002
# 112   Wide_ResNet50_2_Weights.IMAGENET1K_V1  78.468002  94.085999   68.900002
# 113   Wide_ResNet50_2_Weights.IMAGENET1K_V2  81.601997  95.758003   68.900002
#
# [114 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  114 non-null    object
#  1   Acc@1   114 non-null    float32
#  2   Acc@5   114 non-null    float32
#  3   Params  114 non-null    float32
# dtypes: float32(3), object(1)
# memory usage: 2.4+ KB

# %%
best_models = df.loc[df['Acc@1'] > df['Acc@1'].quantile(0.75), :].copy()
best_models['Efficiency'] = best_models['Acc@1'] / best_models['Params']
best_models
# Out:
#                                                Weight      Acc@1      Acc@5  \
# 1                 ConvNeXt_Base_Weights.IMAGENET1K_V1  84.061996  96.870003
# 2                ConvNeXt_Large_Weights.IMAGENET1K_V1  84.414001  96.975998
# 3                ConvNeXt_Small_Weights.IMAGENET1K_V1  83.615997  96.650002
# 14              EfficientNet_B4_Weights.IMAGENET1K_V1  83.384003  96.594002
# 15              EfficientNet_B5_Weights.IMAGENET1K_V1  83.444000  96.627998
# 16              EfficientNet_B6_Weights.IMAGENET1K_V1  84.008003  96.916000
# 17              EfficientNet_B7_Weights.IMAGENET1K_V1  84.122002  96.907997
# 18            EfficientNet_V2_L_Weights.IMAGENET1K_V1  85.807999  97.788002
# 19            EfficientNet_V2_M_Weights.IMAGENET1K_V1  85.112000  97.155998
# 20            EfficientNet_V2_S_Weights.IMAGENET1K_V1  84.227997  96.877998
# 27                     MaxVit_T_Weights.IMAGENET1K_V1  83.699997  96.722000
# ...

# %%
print(f'Il numero minimo di parametri fra i modelli top75% è pari a: {best_models['Params'].min():.2f}')
print(f'Il modello corrispondendente è: [{best_models['Params'].idxmin()}] - {best_models.loc[14,'Weight']}')
# Out:
# Il numero minimo di parametri fra i modelli top75% è pari a: 19.30
# Il modello corrispondendente è: [14] - EfficientNet_B4_Weights.IMAGENET1K_V1
